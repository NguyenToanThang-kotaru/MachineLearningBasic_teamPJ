# %%
from os.path import join
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

data_dir = join('..', '..', 'data')
input_dir = join(data_dir, 'preprocessed')
output_dir = join(data_dir, 'feature_engineered')

train = pd.read_csv(join(input_dir, 'preprocessed_train.csv'))
test = pd.read_csv(join(input_dir, 'preprocessed_test.csv'))

train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0          60         3     4.189655  9.042040       1      1         3
# 1          20         3     4.394449  9.169623       1      1         3
# 2          60         3     4.234107  9.328212       1      1         0
# 3          70         3     4.110874  9.164401       1      1         0
# 4          60         3     4.442651  9.565284       1      1         0
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0            3          0          4  ...       0.0       3      4
# 1            3          0          2  ...       0.0       3      4
# 2            3          0          4  ...       0.0       3      4
# 3            3          0          0  ...       0.0       3      4
# 4            3          0          2  ...       0.0       3      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train['TotalSF'] = train['1stFlrSF'] + train['2ndFlrSF'] + train['TotalBsmtSF']
test['TotalSF'] = test['1stFlrSF'] + test['2ndFlrSF'] + test['TotalBsmtSF']

# %%
# Load dataset
path_dir = join("..", "..", "data")
df = pd.read_csv(join(path_dir, "preprocessed", "preprocessed_train.csv"))
df_test = pd.read_csv(join(path_dir, "preprocessed", "preprocessed_test.csv"))

df.to_csv(join(path_dir, "feature_engineered", "FE_TotalSF", "TotalSF_train.csv"), index=False)
df_test.to_csv(join(path_dir, "feature_engineered", "FE_TotalSF", "TotalSF_test.csv"), index=False)
